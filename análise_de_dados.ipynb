# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoBonifacio001/AugustoBonifacio001/blob/testes_e_exercicios/an%C3%A1lise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
minutos = np.random.randint(0, 60 ,30)
print(minutos)
minutos_ordenados = np.sort(minutos)
print(minutos_ordenados)
# Out:
# [42  9 16 53 25 20 49 40 53 15  1 40 10  6 45 33  0 57 36  6 57 32 33 47
#  51 55 42 42  9 19]
# [ 0  1  6  6  9  9 10 15 16 19 20 25 32 33 33 36 40 40 42 42 42 45 47 49
#  51 53 53 55 57 57]

# %%
ax = sns.histplot(minutos)
ax.set(xlabel= 'Minutos Por Dia', ylabel=' Quantidade De Vezes')
plt.show()

# %%
s1 = pd.Series([1,2,-5,0])
s1
# Out:
# 0    1
# 1    2
# 2   -5
# 3    0
# dtype: int64

# %%
s1.values
# Out:
# array([ 1, -3,  0])

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2 = pd.Series([1,2,-5,0], index =['a','b','c','d'])
s2
# Out:
# a    1
# b    2
# c   -5
# d    0
# dtype: int64

# %%
s2[s2>0]
# Out:
# a    1
# b    2
# dtype: int64

# %%
s2.isnull()
# Out:
# a    False
# b    False
# c    False
# d    False
# dtype: bool

# %%
dados={'estado':['SP','MG','PR','SP','MG','PR'],'ano':[2019,2019,2019,2020,2020,2020], 'pop':[45.9,21.2,16.9,46.6,21.4,17.3]}
df1 = pd.DataFrame(dados)
df1
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2
# 2     PR  2019  16.9
# 3     SP  2020  46.6
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.head(2)
# Out:
#   estado   ano   pop
# 0     SP  2019  45.9
# 1     MG  2019  21.2

# %%
df1.tail(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 5     PR  2020  17.3

# %%
df1.sample(2)
# Out:
#   estado   ano   pop
# 4     MG  2020  21.4
# 0     SP  2019  45.9

# %%
df2 = pd.DataFrame(dados, columns =['ano','estado','pop'])
df2
# Out:
#     ano estado   pop
# 0  2019     SP  45.9
# 1  2019     MG  21.2
# 2  2019     PR  16.9
# 3  2020     SP  46.6
# 4  2020     MG  21.4
# 5  2020     PR  17.3

# %%
df2['estado']
# Out:
# 0    SP
# 1    MG
# 2    PR
# 3    SP
# 4    MG
# 5    PR
# Name: estado, dtype: object

# %%
df2.dtypes
# Out:
# ano         int64
# estado     object
# pop       float64
# dtype: object

# %%
df2['estimativa'] = 50
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9          50
# 1  2019     MG  21.2          50
# 2  2019     PR  16.9          50
# 3  2020     SP  46.6          50
# 4  2020     MG  21.4          50
# 5  2020     PR  17.3          50

# %%
df2['estimativa'] = np.arange(6)
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df3 = df2
df3
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df2['Não Paraná'] = df2.estado !='PR'
df2
# Out:
#     ano estado   pop  estimativa  Não Paraná
# 0  2019     SP  45.9           0        True
# 1  2019     MG  21.2           1        True
# 2  2019     PR  16.9           2       False
# 3  2020     SP  46.6           3        True
# 4  2020     MG  21.4           4        True
# 5  2020     PR  17.3           5       False

# %%
del df2['Não Paraná']

# %%
df2
# Out:
#     ano estado   pop  estimativa
# 0  2019     SP  45.9           0
# 1  2019     MG  21.2           1
# 2  2019     PR  16.9           2
# 3  2020     SP  46.6           3
# 4  2020     MG  21.4           4
# 5  2020     PR  17.3           5

# %%
df2.shape
# Out:
# (6, 4)

# %%
df2.shape[0]
# Out:
# 6

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.columns
# Out:
# Index(['ano', 'estado', 'pop', 'estimativa'], dtype='object')

# %%
df2.count()
# Out:
# ano           6
# estado        6
# pop           6
# estimativa    6
# dtype: int64

# %%
df2.columns=['Ano','Estado','População','Estimativa']
df2
# Out:
#     Ano Estado  População  Estimativa
# 0  2019     SP       45.9           0
# 1  2019     MG       21.2           1
# 2  2019     PR       16.9           2
# 3  2020     SP       46.6           3
# 4  2020     MG       21.4           4
# 5  2020     PR       17.3           5

# %%
df2.describe(include='all')
# Out:
#                 Ano Estado  População  Estimativa
# count      6.000000      6   6.000000    6.000000
# unique          NaN      3        NaN         NaN
# top             NaN     SP        NaN         NaN
# freq            NaN      2        NaN         NaN
# mean    2019.500000    NaN  28.216667    2.500000
# std        0.547723    NaN  14.096725    1.870829
# min     2019.000000    NaN  16.900000    0.000000
# 25%     2019.000000    NaN  18.275000    1.250000
# 50%     2019.500000    NaN  21.300000    2.500000
# 75%     2020.000000    NaN  39.775000    3.750000
# max     2020.000000    NaN  46.600000    5.000000

# %%
df4 = df2
df4.drop('Ano', axis='columns')
# Out:
#   Estado  População  Estimativa
# 0     SP       45.9           0
# 1     MG       21.2           1
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %%
df2
# Out:
#   Estado  População  Estimativa
# 0     SP       45.9           0
# 1     MG       21.2           1
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %%
df2.drop([0,1])
# Out:
#   Estado  População  Estimativa
# 2     PR       16.9           2
# 3     SP       46.6           3
# 4     MG       21.4           4
# 5     PR       17.3           5

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f70beae6-2494-4ba7-a921-16bb8ddcf54c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f70beae6-2494-4ba7-a921-16bb8ddcf54c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(uploaded)
# Out:
# {'teste.csv': b'\r\n\r\na=b + c'}

# %%
import pandas as pd

# %%
teste01 = 'teste.csv'

# %%
df = pd.read_csv(teste01)

# %%
df
# Out:
# Empty DataFrame
# Columns: [a=b + c]
# Index: []
